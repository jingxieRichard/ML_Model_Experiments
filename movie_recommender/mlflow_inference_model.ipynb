# %%
import mlflow 
from surprise import Dataset, SVD, Reader 
import pandas as pd 


def predict(model_url: str, test_data_pd): 
    # prepare test data
    #reader = Reader()
    
    #data = Dataset.load_from_df(ratings[["userId", "movieId", "rating"]], reader)

    # Load model as a PyFuncModel 
    mlflow.set_tracking_uri("http://127.0.0.1:8080/")
    loaded_model = mlflow.sklearn.load_model(model_url)

    # Predict on a Pandas DataFrame.
    predictions = []
    count = 0 
    for _, row in ratings_pd.iterrows(): 
        print(row['userId'], row["movieId"], row["rating"] )
        prediction =  loaded_model.predict(uid=row['userId'], iid=row["movieId"], r_ui=row["rating"] )
        count += 1
        predictions.append(prediction)
        if count == 100:
            break 

    
   
    print("predictions are: \n")
    print(predictions)

# %%
data_path = "data/ml-10M100K/ratings.dat"

ratings_pd = pd.read_csv(data_path, delimiter="::", header=None, names=["userId", "movieId", "rating", "timestamp"])
reader = Reader()
test_data = Dataset.load_from_df(ratings_pd[["userId", "movieId", "rating"]], reader)
# Out:
# /var/folders/z0/hsrwl1n15cl2pyfrkvy3brrm0000gn/T/ipykernel_80914/495171578.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   ratings_pd = pd.read_csv(data_path, delimiter="::", header=None, names=["userId", "movieId", "rating", "timestamp"])

# %%
model_url = 'runs:/5ee564a7dfba424d8de5f4c5152794cc/surprise_svd_movielen_model'

predict(model_url, ratings_pd)
# Out:
# ---------------------------------------------------------------------------
# ConnectionRefusedError                    Traceback (most recent call last)
# File /opt/anaconda3/envs/sf-ml-env/lib/python3.9/site-packages/urllib3/connection.py:174, in HTTPConnection._new_conn(self)
#     173 try:
# --> 174     conn = connection.create_connection(
#     175         (self._dns_host, self.port), self.timeout, **extra_kw
#     176     )
#     178 except SocketTimeout:
#
# File /opt/anaconda3/envs/sf-ml-env/lib/python3.9/site-packages/urllib3/util/connection.py:95, in create_connection(address, timeout, source_address, socket_options)
#      94 if err is not None:
# ---> 95     raise err
#      97 raise socket.error("getaddrinfo returns an empty list")
#
# File /opt/anaconda3/envs/sf-ml-env/lib/python3.9/site-packages/urllib3/util/connection.py:85, in create_connection(address, timeout, source_address, socket_options)
#      84     sock.bind(source_address)
# ---> 85 sock.connect(sa)
# ...
